# %%
import pororo

# %%
from pororo import Pororo

# %%
asr = Pororo(task="asr", lang="en")
# Out:
# 2021-01-15 19:03:34 | INFO | root | Downloading user-selected model...
#
# 2021-01-15 19:03:50 | INFO | root | Downloading user-selected model...

# %%
# Speech recognition of the YouTube link
# You can pass the audio file path to the input. (WAV, FLAC, and MP3)
asr('https://www.youtube.com/watch?v=6Af6b_wyiwI', batch_size=1)
# Out:
# Removing cache dir /root/.cache/youtube-dl ..
# [youtube] 6Af6b_wyiwI: Downloading webpage
# [youtube] Downloading just video 6Af6b_wyiwI because of --no-playlist
# [youtube] 6Af6b_wyiwI: Downloading webpage
# [youtube] Downloading just video 6Af6b_wyiwI because of --no-playlist
# [download] 6Af6b_wyiwI.wav has already been downloaded
# [download] 100% of 7.69MiB
# [ffmpeg] Post-process file 6Af6b_wyiwI.wav exists, skipping
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# {'audio': 'https://www.youtube.com/watch?v=6Af6b_wyiwI',
#  'duration': '0:08:36.794937',
#  'results': [{'speech_section': '0:00:00 ~ 0:00:19',
#    'length_ms': 18980.0,
#    'speech': 'WHEN I WAS A KID'},
#   {'speech_section': '0:00:19 ~ 0:00:21',
#    'length_ms': 2050.0,
#    'speech': 'THE DISASTER WE WORRIED ABOUT MOST'},
# ...

# %%
asr = Pororo(task="asr", lang="ko")

# %%
asr('https://www.youtube.com/watch?v=AQiVdRGH6aM', batch_size=1)
# Out:
# Removing cache dir /root/.cache/youtube-dl ..
# [youtube] AQiVdRGH6aM: Downloading webpage
# [youtube] Downloading just video AQiVdRGH6aM because of --no-playlist
# [youtube] AQiVdRGH6aM: Downloading webpage
# [youtube] Downloading just video AQiVdRGH6aM because of --no-playlist
# [download] AQiVdRGH6aM.wav has already been downloaded
# [download] 100% of 16.72MiB
# [ffmpeg] Correcting container in "AQiVdRGH6aM.wav"
# [ffmpeg] Post-process file AQiVdRGH6aM.wav exists, skipping
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# {'audio': 'https://www.youtube.com/watch?v=AQiVdRGH6aM',
#  'duration': '0:18:03.837875',
#  'results': [{'speech_section': '0:00:00 ~ 0:00:01',
#    'length_ms': 1180.0,
#    'speech': '그래서'},
#   {'speech_section': '0:00:01 ~ 0:00:02', 'length_ms': 900.0, 'speech': '그래서'},
#   {'speech_section': '0:00:02 ~ 0:00:06',
# ...
