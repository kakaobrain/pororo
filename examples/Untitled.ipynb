# %%
from pororo import Pororo

# %%
tts = Pororo("tts", lang="multi")

# %%
tts("안녕?", lang="ko")
# Out:
# array([ -1.1970111,   2.2198403,  -3.0649855, ..., -22.05273  ,
#        -17.553982 ,  -4.1367397], dtype=float32)

# %%
tts("안녕?", lang="ko", speaker="en")
# Out:
# array([ -23.768461 ,   -2.5586517,    7.172303 , ...,   50.152203 ,
#        -173.97281  , -176.26869  ], dtype=float32)

# %%
import IPython

audio = tts("나머지 세 강의는 각각 한 시간 씩이야.", lang="ko", speaker="en-15,fr")
IPython.display.Audio(audio, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
audio = tts("How are you?", lang="en")
IPython.display.Audio(audio, rate=22050)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
