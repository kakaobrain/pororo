# %%
import pororo

# %%
from pororo import Pororo

# %%
# Supported source languages: english, chinese, korean
st = Pororo(task="st", lang="en")

# %%
st("english_speech.flac", tgt="ko")
# Out:
# {'asr_outputs': [{'speech_section': '0:00:00 ~ 0:00:06',
#    'length_ms': 6260.0,
#    'speech': 'AND THIS CONTRACTED SPACE OF MODERN BENGAL IT WAS DOUBTFUL IF THE PEERLESS CREATURE EXISTED AS YET'}],
#  'mt_outputs': ['그리고 이 근대 봉갈의 이 계약 공간은 아직까지 동료 없는 생명체가 존재했는지 의문이 들었다']}

# %%
st("https://www.youtube.com/watch?v=6Af6b_wyiwI", tgt="ko")
# Out:
# Removing cache dir /root/.cache/youtube-dl ..
# [youtube] 6Af6b_wyiwI: Downloading webpage
# [youtube] Downloading just video 6Af6b_wyiwI because of --no-playlist
# [youtube] 6Af6b_wyiwI: Downloading webpage
# [youtube] Downloading just video 6Af6b_wyiwI because of --no-playlist
# [download] 6Af6b_wyiwI.wav has already been downloaded
# [download] 100% of 7.69MiB
# [ffmpeg] Post-process file 6Af6b_wyiwI.wav exists, skipping
# /opt/conda/lib/python3.7/site-packages/librosa/core/audio.py:162: UserWarning: PySoundFile failed. Trying audioread instead.
#   warnings.warn("PySoundFile failed. Trying audioread instead.")
# {'asr_outputs': [{'speech_section': '0:00:00 ~ 0:00:19',
#    'length_ms': 18980.0,
#    'speech': 'WHEN I WAS A KID'},
#   {'speech_section': '0:00:19 ~ 0:00:21',
#    'length_ms': 2050.0,
#    'speech': 'THE DISASTER WE WORRIED ABOUT MOST'},
#   {'speech_section': '0:00:21 ~ 0:00:23',
#    'length_ms': 1540.0,
#    'speech': 'WAS A NUCLEOR WAR'},
# ...

# %%
st = Pororo(task="st", lang="ko")

# %%
st("korean_speech.wav", tgt="en")
# Out:
# {'asr_outputs': [{'speech_section': '0:00:00 ~ 0:00:06',
#    'length_ms': 5870.0,
#    'speech': '맞아 시간 안에 풀고 약간 이것부터 풀고 요런 식으로 풀어보렴 이런 거'}],
#  'mt_outputs': ["That's right, let's solve it in time and let it go a little bit, and then let it go like this."]}
